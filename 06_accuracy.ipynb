# %% [markdown]
# # Accuracy Analysis
#
# ### Method
# Data values must match authoritative interal or external source of truth (Central database or regional database, CRM, product catalog)
# ### Result
# ** Score : Not Accessed **
# No source data was available for cross-referencing. The five other dimensions access internal integrity but cannot confirm real-world accuracy
# ### Recommendation
# Sample 100 records of Order Ids and cross-referennce Sales, Profit, and Product ID and Product Name against the financial system of record before using this dataset for executing  reporting.
